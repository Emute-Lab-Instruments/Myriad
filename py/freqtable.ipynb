# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
m = arange(4096) / 4096.0 * 10.0

# %%
plot(m)

# %%
m
# Out:
# array([0.00000000e+00, 2.44140625e-03, 4.88281250e-03, ...,
#        9.99267578e+00, 9.99511719e+00, 9.99755859e+00])

# %%
freqs = [440 *pow(2,(x-5.0)/1.0) for x in m]
plot(freqs)

# %%
wavelens = [(1/x) * 1600000 for x in freqs]

# %%
plot(wavelens)

# %%
wavelens[0]
# Out:
# 116363.63636363635

# %%
intwavlens = [int(round(x)) for x in wavelens]

# %%
plot(intwavlens)

# %%
len(intwavlens)
# Out:
# 4096

# %%
print(intwavlens)
# Out:
# [116364, 116167, 115970, 115774, 115579, 115383, 115188, 114993, 114799, 114605, 114411, 114218, 114024, 113832, 113639, 113447, 113255, 113064, 112873, 112682, 112491, 112301, 112111, 111922, 111732, 111543, 111355, 111167, 110979, 110791, 110604, 110417, 110230, 110043, 109857, 109672, 109486, 109301, 109116, 108932, 108748, 108564, 108380, 108197, 108014, 107831, 107649, 107467, 107285, 107104, 106923, 106742, 106562, 106381, 106202, 106022, 105843, 105664, 105485, 105307, 105129, 104951, 104773, 104596, 104419, 104243, 104067, 103891, 103715, 103540, 103365, 103190, 103015, 102841, 102667, 102494, 102320, 102147, 101975, 101802, 101630, 101458, 101287, 101115, 100944, 100774, 100603, 100433, 100264, 100094, 99925, 99756, 99587, 99419, 99251, 99083, 98915, 98748, 98581, 98414, 98248, 98082, 97916, 97750, 97585, 97420, 97255, 97091, 96927, 96763, 96599, 96436, 96273, 96110, 95948, 95785, 95624, 95462, 95300, 95139, 94978, 94818, 94657, 94497, 94338, 94178, 94019, 93860, 93701, 9354
# ...

# %%
import pyperclip

# %%
pyperclip.copy(intwavlens)
